# %%
from utils.shock_model import ShockModel
to_git = True

# %% [markdown]
# ## Serie A

# %%
model = ShockModel('Serie_A', 2023, 1_000_000, home_away_pars = 0, to_git = to_git)
model.run_model()
# Out:
# Parameters didn't converge
# Parameters converged after 2 iteration(s)!
# 100%|██████████| 380/380 [03:04<00:00,  2.06it/s]

# %%
model = ShockModel('Serie_A', 2023, 1_000_000, home_away_pars = 1, to_git = to_git)
model.run_model()
# Out:
# Parameters converged after 1 iteration(s)!
# 100%|██████████| 380/380 [03:17<00:00,  1.93it/s]

# %%
model = ShockModel('Serie_A', 2023, 1_000_000, home_away_pars = 20, to_git = to_git)
model.run_model()
# Out:
# Parameters converged after 1 iteration(s)!
# 100%|██████████| 380/380 [03:01<00:00,  2.10it/s]

# %%
model = ShockModel('Serie_A', 2023, 1_000_000, home_away_pars = 40, to_git = to_git)
model.run_model()
# Out:
# Parameters didn't converge
# Parameters didn't converge
# Parameters converged after 3 iteration(s)!
# 100%|██████████| 380/380 [02:50<00:00,  2.23it/s]

# %% [markdown]
# ## Serie B

# %%
model = ShockModel('Serie_B', 2023, 1_000_000, home_away_pars = 0, to_git = to_git)
model.run_model()
# Out:
# Parameters converged after 1 iteration(s)!
# 100%|██████████| 380/380 [02:08<00:00,  2.95it/s]

# %%
model = ShockModel('Serie_B', 2023, 1_000_000, home_away_pars = 1, to_git = to_git)
model.run_model()
# Out:
# Parameters converged after 1 iteration(s)!
# 100%|██████████| 380/380 [02:10<00:00,  2.92it/s]

# %%
model = ShockModel('Serie_B', 2023, 1_000_000, home_away_pars = 20, to_git = to_git)
model.run_model()
# Out:
# Parameters converged after 1 iteration(s)!
# 100%|██████████| 380/380 [02:11<00:00,  2.88it/s]

# %%
model = ShockModel('Serie_B', 2023, 1_000_000, home_away_pars = 40, to_git = to_git)
model.run_model()
# Out:
# Parameters converged after 1 iteration(s)!
# 100%|██████████| 380/380 [1:29:53<00:00, 14.19s/it]
