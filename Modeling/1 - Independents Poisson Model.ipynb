# %%
from utils.independents_poisson_model import IndependentsPoissonModel
to_git = True

# %% [markdown]
# ## Serie A

# %%
model = IndependentsPoissonModel('Serie_A', 2023, 1_000_000, home_away_pars = 0, to_git = to_git)
model.run_model()
# Out:
# Parameters converged after 1 iteration(s)!
# 100%|██████████| 380/380 [02:08<00:00,  2.96it/s]

# %%
model = IndependentsPoissonModel('Serie_A', 2023, 1_000_000, home_away_pars = 1, to_git = to_git)
model.run_model()
# Out:
# Parameters converged after 1 iteration(s)!
# 100%|██████████| 380/380 [02:04<00:00,  3.05it/s]

# %%
model = IndependentsPoissonModel('Serie_A', 2023, 1_000_000, home_away_pars = 20, to_git = to_git)
model.run_model()
# Out:
# Parameters converged after 1 iteration(s)!
# 100%|██████████| 380/380 [02:03<00:00,  3.09it/s]

# %%
model = IndependentsPoissonModel('Serie_A', 2023, 1_000_000, home_away_pars = 40, to_git = to_git)
model.run_model()
# Out:
# Parameters didn't converge
# Parameters converged after 2 iteration(s)!
# 100%|██████████| 380/380 [02:01<00:00,  3.13it/s]

# %% [markdown]
# ## Serie B

# %%
model = IndependentsPoissonModel('Serie_B', 2023, 1_000_000, home_away_pars = 0, to_git = to_git)
model.run_model()
# Out:
# Parameters converged after 1 iteration(s)!
# 100%|██████████| 380/380 [01:31<00:00,  4.13it/s]

# %%
model = IndependentsPoissonModel('Serie_B', 2023, 1_000_000, home_away_pars = 1, to_git = to_git)
model.run_model()
# Out:
# Parameters converged after 1 iteration(s)!
# 100%|██████████| 380/380 [01:34<00:00,  4.03it/s]

# %%
model = IndependentsPoissonModel('Serie_B', 2023, 1_000_000, home_away_pars = 20, to_git = to_git)
model.run_model()
# Out:
# Parameters converged after 1 iteration(s)!
# 100%|██████████| 380/380 [01:31<00:00,  4.16it/s]

# %%
model = IndependentsPoissonModel('Serie_B', 2023, 1_000_000, home_away_pars = 40, to_git = to_git)
model.run_model()
# Out:
# Parameters converged after 1 iteration(s)!
# 100%|██████████| 380/380 [01:29<00:00,  4.26it/s]
